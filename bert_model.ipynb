# %%
import pdb
import json
import pickle
import argparse
import pandas as pd
import networkx as nx
from collections import Counter
# import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# sns.set(font_scale=1.5)
import matplotlib.pyplot as plt
from datetime import datetime, timezone
from google.colab import drive
drive.mount('/content/drive')

# 安装huggingface transformers（版本大于4.3.0）:
# !pip install transformers
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased") 
model = AutoModel.from_pretrained("bert-base-cased")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-f004061a9480> in <module>
#      13 from datetime import datetime, timezone
#      14 from google.colab import drive
# ---> 15 drive.mount('/content/drive')
#      16
#      17 # 安装huggingface transformers（版本大于4.3.0）:
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      99 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     100   """Mount your Google Drive at the specified mountpoint path."""
# --> 101   return _mount(
#     102       mountpoint,
#     103       force_remount=force_remount,
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
# ...

# %%
data = pd.read_csv("/content/drive/MyDrive/code/bert_related/labeled_data.csv", index_col = False)
data = data[data['agreement_fraction']==1.000000]
bb = data[["author_parent","author_child",'label','datetime','subreddit','body_parent', 'body_child']]
bb_sub = data[['body_parent', 'body_child']]

# %%
par_text_list = list(bb_sub['body_parent'])
chi_text_list = list(bb_sub['body_child'])

# %%
# bert model for par

par_batch0 = tokenizer(par_text_list[0], padding=True, truncation=True, return_tensors="pt")
par_output0 = model(**par_batch0).pooler_output.detach().numpy()

for i in range(1,len(par_text_list)):
  print(i)
  per_par_batch = tokenizer(par_text_list[i], padding=True, truncation=True, return_tensors="pt")
  per_par_out = model(**per_par_batch).pooler_output.detach().numpy()
  par_output0 = np.concatenate((par_output0,per_par_out), axis=0)

# par_output0.shape
# aa = pd.DataFrame(par_output0)
# # aa.to_csv('ber_par.csv')
# bb = pd.read_csv('ber_par.csv',index_col=[0])

# %%
par_output0.shape
aa = pd.DataFrame(par_output0)
# aa.to_csv('ber_par.csv')
bb = pd.read_csv('ber_par.csv',index_col=[0])

# %%
# bert model for child

chi_batch0 = tokenizer(chi_text_list[0], padding=True, truncation=True, return_tensors="pt")
chi_output0 = model(**chi_batch0).pooler_output.detach().numpy()

for i in range(1,len(chi_text_list)):
  # print(i)
  per_chi_batch = tokenizer(chi_text_list[i], padding=True, truncation=True, return_tensors="pt")
  per_chi_out = model(**per_chi_batch).pooler_output.detach().numpy()
  chi_output0 = np.concatenate((chi_output0,per_chi_out), axis=0)

chi_output_df = pd.DataFrame(chi_output0)
# chi_output_df.to_csv('ber_chi.csv')
chi_output_df = pd.read_csv('ber_chi.csv',index_col=[0])

# %% [markdown]
# # New section
